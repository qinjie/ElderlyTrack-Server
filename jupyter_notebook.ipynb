# %%
import json
import datetime
import os

import pymysql
import boto3
from chalice import Chalice, NotFoundError, ChaliceViewError, CognitoUserPoolAuthorizer
from chalice import IAMAuthorizer
from chalice import BadRequestError
from chalicelib.db.base import session_factory
from chalicelib.db.models import *
from chalicelib.db.schemas import *
import contextlib

# %%
with contextlib.closing(session_factory()) as session:
    a = session.query(Missing).all()
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# <ipython-input-30-1be0aa7f2fd1> in <module>()
#       1 with contextlib.closing(session_factory()) as session:
# ----> 2     a = session.query(Missing).all()
#
# /anaconda3/lib/python3.6/site-packages/sqlalchemy/orm/session.py in query(self, *entities, **kwargs)
#    1397         :class:`.Session`."""
#    1398
# -> 1399         return self._query_cls(entities, self, **kwargs)
#    1400
#    1401     @property
#
# /anaconda3/lib/python3.6/site-packages/sqlalchemy/orm/query.py in __init__(self, entities, session)
#     140         self.session = session
#     141         self._polymorphic_adapters = {}
# --> 142         self._set_entities(entities)
#     143
#     144     def _set_entities(self, entities, entity_wrapper=None):
#
# /anaconda3/lib/python3.6/site-packages/sqlalchemy/orm/query.py in _set_entities(self, entities, entity_wrapper)
#     152                 entity_wrapper(self, ent)
#     153
# --> 154             self._set_entity_selectables(self._entities)
#     155
#     156     def _set_entity_selectables(self, entities):
#
# /anaconda3/lib/python3.6/site-packages/sqlalchemy/orm/query.py in _set_entity_selectables(self, entities)
#     182                         aliased_adapter
#     183                     )
# --> 184                 ent.setup_entity(*d[entity])
#     185
#     186     def _mapper_loads_polymorphically_with(self, mapper, adapter):
#
# /anaconda3/lib/python3.6/site-packages/sqlalchemy/orm/query.py in setup_entity(self, ext_info, aliased_adapter)
#    3676         self.selectable = ext_info.selectable
#    3677         self.is_aliased_class = ext_info.is_aliased_class
# -> 3678         self._with_polymorphic = ext_info.with_polymorphic_mappers
#    3679         self._polymorphic_discriminator = \
#    3680             ext_info.polymorphic_on
#
# /anaconda3/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __get__(self, obj, cls)
#     765         if obj is None:
#     766             return self
# --> 767         obj.__dict__[self.__name__] = result = self.fget(obj)
#     768         return result
#     769
#
# /anaconda3/lib/python3.6/site-packages/sqlalchemy/orm/mapper.py in _with_polymorphic_mappers(self)
#    2009     def _with_polymorphic_mappers(self):
#    2010         if Mapper._new_mappers:
# -> 2011             configure_mappers()
#    2012         if not self.with_polymorphic:
#    2013             return []
#
# /anaconda3/lib/python3.6/site-packages/sqlalchemy/orm/mapper.py in configure_mappers()
#    3024                         % (mapper, mapper._configure_failed))
#    3025                     e._configure_failed = mapper._configure_failed
# -> 3026                     raise e
#    3027                 if not mapper.configured:
#    3028                     try:
#
# InvalidRequestError: One or more mappers failed to initialize - can't proceed with initialization of other mappers. Triggering mapper: 'Mapper|Resident|resident'. Original exception was: relationship 'missings' expects a class or a mapper argument (received: <class 'sqlalchemy.sql.schema.Table'>)

# %%
with contextlib.closing(session_factory()) as session:
    user = session.query(User).filter(User.email == email).first()
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# <ipython-input-21-faef16ec175b> in <module>()
#       1 with contextlib.closing(session_factory()) as session:
# ----> 2     user = session.query(User).filter(User.email == email).first()
#
# /anaconda3/lib/python3.6/site-packages/sqlalchemy/orm/session.py in query(self, *entities, **kwargs)
#    1397         :class:`.Session`."""
#    1398
# -> 1399         return self._query_cls(entities, self, **kwargs)
#    1400
#    1401     @property
#
# /anaconda3/lib/python3.6/site-packages/sqlalchemy/orm/query.py in __init__(self, entities, session)
#     140         self.session = session
#     141         self._polymorphic_adapters = {}
# --> 142         self._set_entities(entities)
#     143
#     144     def _set_entities(self, entities, entity_wrapper=None):
#
# /anaconda3/lib/python3.6/site-packages/sqlalchemy/orm/query.py in _set_entities(self, entities, entity_wrapper)
#     152                 entity_wrapper(self, ent)
#     153
# --> 154             self._set_entity_selectables(self._entities)
#     155
#     156     def _set_entity_selectables(self, entities):
#
# /anaconda3/lib/python3.6/site-packages/sqlalchemy/orm/query.py in _set_entity_selectables(self, entities)
#     182                         aliased_adapter
#     183                     )
# --> 184                 ent.setup_entity(*d[entity])
#     185
#     186     def _mapper_loads_polymorphically_with(self, mapper, adapter):
#
# /anaconda3/lib/python3.6/site-packages/sqlalchemy/orm/query.py in setup_entity(self, ext_info, aliased_adapter)
#    3676         self.selectable = ext_info.selectable
#    3677         self.is_aliased_class = ext_info.is_aliased_class
# -> 3678         self._with_polymorphic = ext_info.with_polymorphic_mappers
#    3679         self._polymorphic_discriminator = \
#    3680             ext_info.polymorphic_on
#
# /anaconda3/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __get__(self, obj, cls)
#     765         if obj is None:
#     766             return self
# --> 767         obj.__dict__[self.__name__] = result = self.fget(obj)
#     768         return result
#     769
#
# /anaconda3/lib/python3.6/site-packages/sqlalchemy/orm/mapper.py in _with_polymorphic_mappers(self)
#    2009     def _with_polymorphic_mappers(self):
#    2010         if Mapper._new_mappers:
# -> 2011             configure_mappers()
#    2012         if not self.with_polymorphic:
#    2013             return []
#
# /anaconda3/lib/python3.6/site-packages/sqlalchemy/orm/mapper.py in configure_mappers()
#    3024                         % (mapper, mapper._configure_failed))
#    3025                     e._configure_failed = mapper._configure_failed
# -> 3026                     raise e
#    3027                 if not mapper.configured:
#    3028                     try:
#
# InvalidRequestError: One or more mappers failed to initialize - can't proceed with initialization of other mappers. Triggering mapper: 'Mapper|Resident|resident'. Original exception was: relationship 'missings' expects a class or a mapper argument (received: <class 'sqlalchemy.sql.schema.Table'>)

# %%
import base64
import datetime
from uuid import uuid4
import hashlib
import hmac
import os

import jwt
from chalice import UnauthorizedError

JWT_SECRET = b'\xf7\xb6k\xabP\xce\xc1\xaf\xad\x86\xcf\x84\x02\x80\xa0\xe0'

def gen_jwt_token(data):
    now = datetime.datetime.utcnow()
    unique_id = str(uuid4())
    payload = {
        'sub': data,
        'iat': now,
        'nbf': now,
        'jti': unique_id,
        # NOTE: We can also add 'exp' if we want tokens to expire.
    }
    return jwt.encode(payload, JWT_SECRET, algorithm='HS256')

result = gen_jwt_token(",5")
print(result.decode())
# Out:
# eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJzdWIiOiIsNSIsImlhdCI6MTUyOTgyNzcyNCwibmJmIjoxNTI5ODI3NzI0LCJqdGkiOiI2ZTJjNThiNi1hNzI1LTQ5ZjEtYTBlNS1hOTZkODA2NjJmZGYifQ.DhPNKRfwNsjVNImAk7EcbDMC-O33VM-_4pTWpiAHB6U
